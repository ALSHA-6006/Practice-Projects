# %%
import pandas as pd
column_names=['Id number','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type of glass']
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Glass%20Identification/Glass%20Identification.csv',names=column_names)
df
# Out:
#      Id number       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  \
# 0            1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1            2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2            3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3            4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4            5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..         ...      ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209        210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210        211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211        212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212        213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213        214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
#      Type of glass
# 0                1
# 1                1
# 2                1
# ...

# %%
df.skew()
# Out:
# Id number        0.000000
# RI               1.625431
# Na               0.454181
# Mg              -1.152559
# Al               0.907290
# Si              -0.730447
# K                6.551648
# Ca               2.047054
# Ba               3.416425
# Fe               1.754327
# Type of glass    1.114915
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id number      214 non-null    int64
#  1   RI             214 non-null    float64
#  2   Na             214 non-null    float64
#  3   Mg             214 non-null    float64
#  4   Al             214 non-null    float64
#  5   Si             214 non-null    float64
#  6   K              214 non-null    float64
#  7   Ca             214 non-null    float64
#  8   Ba             214 non-null    float64
#  9   Fe             214 non-null    float64
#  10  Type of glass  214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %% [markdown]
# No null values exist in the dataset

# %%
df.describe()
# Out:
#         Id number          RI          Na          Mg          Al          Si  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean   107.500000    1.518365   13.407850    2.684533    1.444907   72.650935
# std     61.920648    0.003037    0.816604    1.442408    0.499270    0.774546
# min      1.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     54.250000    1.516522   12.907500    2.115000    1.190000   72.280000
# 50%    107.500000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    160.750000    1.519157   13.825000    3.600000    1.630000   73.087500
# max    214.000000    1.533930   17.380000    4.490000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe  Type of glass
# count  214.000000  214.000000  214.000000  214.000000     214.000000
# mean     0.497056    8.956963    0.175047    0.057009       2.780374
# ...

# %%
df['Ca'].mean()
# Out:
# 8.95696261682243

# %%
df['Ca'].median()
# Out:
# 8.6

# %%
df['K'].mode()
# Out:
# 0    0.0
# Name: K, dtype: float64

# %% [markdown]
# There is a huge difference between the 75% and 100% quantile of 'K', 'Ca','Ba' of these column. So there is existence of outliers
#
# Std value of Id number is very high, so there is existence of outliers

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.distplot(df['K'])
# Out:
# <Axes: xlabel='K', ylabel='Density'>

# %% [markdown]
# Positive Skewness (Mean > Median > Mode)

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.distplot(df['Mg'])
# Out:
# <Axes: xlabel='Mg', ylabel='Density'>

# %%
import seaborn as sns
sns.distplot(df['Si'])
# Out:
# <Axes: xlabel='Si', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.distplot(df['Ca'])
# Out:
# <Axes: xlabel='Ca', ylabel='Density'>

# %% [markdown]
# Positive Skewness (Mean > Median > Mode)

# %%
sns.boxplot(df['K'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Ca'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Ba'])
# Out:
# <Axes: >

# %%
df_corr=df.corr()
df_corr
# Out:
#                Id number        RI        Na        Mg        Al        Si  \
# Id number       1.000000 -0.217248  0.689293 -0.902241  0.776445  0.197846
# RI             -0.217248  1.000000 -0.340105 -0.022475 -0.568836 -0.657444
# Na              0.689293 -0.340105  1.000000 -0.523895  0.516221  0.139741
# Mg             -0.902241 -0.022475 -0.523895  1.000000 -0.663276 -0.162993
# Al              0.776445 -0.568836  0.516221 -0.663276  1.000000  0.214380
# Si              0.197846 -0.657444  0.139741 -0.162993  0.214380  1.000000
# K              -0.018646 -0.455755 -0.231271  0.113800  0.435190 -0.098610
# Ca              0.005979  0.915958 -0.307408 -0.296930 -0.404164 -0.389125
# Ba              0.810868 -0.192080  0.678764 -0.765738  0.771881  0.022047
# Fe             -0.422324  0.331791 -0.548781  0.344884 -0.386056 -0.238377
# Type of glass   0.981321 -0.312757  0.751122 -0.897160  0.823059  0.266781
#
#                       K        Ca        Ba        Fe  Type of glass
# ...

# %%
sns.heatmap(df_corr,annot=True)
# Out:
# <Axes: >

# %%
import scipy
from scipy.stats import zscore

# %%
import numpy as np
z=np.abs(zscore(df))
z
# Out:
#      Id number        RI        Na        Mg        Al        Si         K  \
# 0     1.723976  0.872868  0.284953  1.254639  0.692442  1.127082  0.671705
# 1     1.707788  0.249333  0.591817  0.636168  0.170460  0.102319  0.026213
# 2     1.691601  0.721318  0.149933  0.601422  0.190912  0.438787  0.164533
# 3     1.675413  0.232831  0.242853  0.698710  0.310994  0.052974  0.112107
# 4     1.659226  0.312045  0.169205  0.650066  0.411375  0.555256  0.081369
# ..         ...       ...       ...       ...       ...       ...       ...
# 209   1.659226  0.704815  0.898681  1.865511  2.881125  0.052974  0.640968
# 210   1.675413  0.500178  1.856097  1.865511  1.094342  0.529374  0.763919
# 211   1.691601  0.754046  1.168721  1.865511  1.154570  0.995252  0.763919
# 212   1.707788  0.612399  1.193270  1.865511  0.993960  1.241133  0.763919
# 213   1.723976  0.414363  1.009152  1.865511  1.275028  0.917606  0.763919
#
#            Ca        Ba        Fe  Type of glass
# ...

# %%
threshold=3
np.where(z>3)
# Out:
# (array([105, 106, 106, 106, 106, 106, 107, 107, 107, 110, 111, 112, 112,
#         131, 145, 162, 163, 163, 163, 171, 171, 172, 172, 174, 184, 184,
#         188, 189, 201, 201, 203, 207, 213], dtype=int64),
#  array([7, 1, 2, 5, 7, 8, 1, 5, 7, 7, 7, 1, 7, 7, 9, 9, 4, 5, 8, 4, 6, 4,
#         6, 9, 2, 5, 5, 8, 5, 6, 8, 8, 8], dtype=int64))

# %%
z.iloc[105,7]
# Out:
# 3.01659640155971

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      Id number       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  \
# 0            1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1            2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2            3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3            4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4            5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..         ...      ...    ...   ...   ...    ...   ...   ...   ...  ...
# 208        209  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.0
# 209        210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210        211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211        212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212        213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
#
#      Type of glass
# 0                1
# 1                1
# 2                1
# ...

# %%
df.shape
# Out:
# (214, 11)

# %%
df_new.shape
# Out:
# (194, 11)

# %% [markdown]
# 20 rows have been removed from the dataset (# outliers have been removed)

# %%
x=df.iloc[:,:-1]
x
# Out:
#      Id number       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0            1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1            2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2            3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3            4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4            5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..         ...      ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209        210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210        211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211        212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212        213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213        214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 10 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type of glass, Length: 214, dtype: int64

# %%
import sklearn
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
x_train
# Out:
#      Id number       RI     Na    Mg    Al     Si     K     Ca    Ba    Fe
# 35          36  1.51567  13.29  3.45  1.21  72.74  0.56   8.57  0.00  0.00
# 28          29  1.51768  12.56  3.52  1.43  73.15  0.57   8.54  0.00  0.00
# 42          43  1.51779  13.21  3.39  1.33  72.76  0.59   8.59  0.00  0.00
# 82          83  1.51646  13.41  3.55  1.25  72.81  0.68   8.10  0.00  0.00
# 100        101  1.51655  12.75  2.85  1.44  73.27  0.57   8.79  0.11  0.22
# ..         ...      ...    ...   ...   ...    ...   ...    ...   ...   ...
# 106        107  1.53125  10.73  0.00  2.10  69.81  0.58  13.30  3.15  0.28
# 14          15  1.51763  12.61  3.59  1.31  73.29  0.58   8.50  0.00  0.00
# 92          93  1.51588  13.12  3.41  1.58  73.26  0.07   8.39  0.00  0.19
# 179        180  1.51852  14.09  2.19  1.66  72.67  0.00   9.32  0.00  0.00
# 102        103  1.51820  12.62  2.76  0.83  73.81  0.35   9.42  0.00  0.20
#
# [143 rows x 10 columns]

# %%
x_train.shape
# Out:
# (143, 10)

# %%
x_test
# Out:
#      Id number       RI     Na    Mg    Al     Si     K     Ca    Ba    Fe
# 9           10  1.51755  13.00  3.60  1.36  72.99  0.57   8.40  0.00  0.11
# 197        198  1.51727  14.70  0.00  2.34  73.28  0.00   8.95  0.66  0.00
# 66          67  1.52152  13.05  3.65  0.87  72.22  0.19   9.85  0.00  0.17
# 191        192  1.51602  14.85  0.00  2.38  73.28  0.00   8.76  0.64  0.09
# 117        118  1.51708  13.72  3.68  1.81  72.06  0.64   7.88  0.00  0.00
# ..         ...      ...    ...   ...   ...    ...   ...    ...   ...   ...
# 65          66  1.52099  13.69  3.59  1.12  71.96  0.09   9.40  0.00  0.00
# 108        109  1.52222  14.43  0.00  1.00  72.67  0.10  11.52  0.00  0.08
# 181        182  1.51888  14.99  0.78  1.74  72.50  0.00   9.95  0.00  0.00
# 31          32  1.51747  12.84  3.50  1.14  73.27  0.56   8.55  0.00  0.00
# 12          13  1.51589  12.88  3.43  1.40  73.28  0.69   8.05  0.00  0.24
#
# [71 rows x 10 columns]

# %%
x_test.shape
# Out:
# (71, 10)

# %%
y_train
# Out:
# 35     1
# 28     1
# 42     1
# 82     2
# 100    2
#       ..
# 106    2
# 14     1
# 92     2
# 179    6
# 102    2
# Name: Type of glass, Length: 143, dtype: int64

# %%
y_train.shape
# Out:
# (143,)

# %%
y_test
# Out:
# 9      1
# 197    7
# 66     1
# 191    7
# 117    2
#       ..
# 65     1
# 108    2
# 181    6
# 31     1
# 12     1
# Name: Type of glass, Length: 71, dtype: int64

# %%
y_test.shape
# Out:
# (71,)

# %%
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
lg=LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred=lg.predict(x_test)
pred
# Out:
# array([1, 7, 1, 7, 2, 2, 1, 2, 2, 2, 6, 5, 2, 2, 6, 5, 7, 1, 1, 6, 2, 7,
#        7, 7, 3, 2, 1, 1, 5, 1, 1, 2, 3, 2, 2, 7, 5, 3, 2, 2, 2, 7, 1, 2,
#        3, 2, 2, 2, 2, 2, 1, 1, 1, 2, 1, 1, 7, 2, 5, 1, 1, 2, 1, 7, 5, 2,
#        1, 2, 6, 1, 1], dtype=int64)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9859154929577465

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[21,  1,  0,  0,  0,  0],
#        [ 0, 25,  0,  0,  0,  0],
#        [ 0,  0,  4,  0,  0,  0],
#        [ 0,  0,  0,  6,  0,  0],
#        [ 0,  0,  0,  0,  4,  0],
#        [ 0,  0,  0,  0,  0, 10]], dtype=int64)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.95      0.98        22
#            2       0.96      1.00      0.98        25
#            3       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         6
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00        10
#
#     accuracy                           0.99        71
#    macro avg       0.99      0.99      0.99        71
# weighted avg       0.99      0.99      0.99        71
